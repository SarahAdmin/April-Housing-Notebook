# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahAdmin/April-Housing-Notebook/blob/main/April_Housing_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
averageDF = pd.read_csv('Average-prices-2025-04.csv',encoding='latin-1')
final_average = averageDF.head(200)
final_average.style.background_gradient(cmap='gist_rainbow')
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:3807: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:3808: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_69954_row0_col3, #T_69954_row11_col3, #T_69954_row23_col3, #T_69954_row99_col3, #T_69954_row109_col3, #T_69954_row119_col3 {
#   background-color: #20ff00;
#   color: #000000;
# }
# ...

# %%
salesDF = pd.read_csv('Sales-2025-04.csv',encoding='latin-1')
final_sales = salesDF.head(200)
final_sales.style.background_gradient(cmap='gist_rainbow')
# Out:
# <style type="text/css">
# #T_362c2_row0_col3 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_362c2_row1_col3, #T_362c2_row12_col3, #T_362c2_row17_col3 {
#   background-color: #ff0d00;
#   color: #f1f1f1;
# }
# #T_362c2_row2_col3 {
#   background-color: #ff2800;
#   color: #f1f1f1;
# }
# #T_362c2_row3_col3, #T_362c2_row11_col3 {
#   background-color: #ff5800;
#   color: #f1f1f1;
# }
# #T_362c2_row4_col3 {
#   background-color: #ffaf00;
#   color: #000000;
# }
# #T_362c2_row5_col3, #T_362c2_row6_col3 {
#   background-color: #ff7e00;
#   color: #f1f1f1;
# }
# #T_362c2_row7_col3 {
#   background-color: #ffd500;
#   color: #000000;
# }
# #T_362c2_row8_col3 {
#   background-color: #ff4e00;
#   color: #f1f1f1;
# }
# #T_362c2_row9_col3 {
#   background-color: #ff6900;
#   color: #f1f1f1;
# }
# #T_362c2_row10_col3 {
#   background-color: #ff4800;
#   color: #f1f1f1;
# }
# #T_362c2_row13_col3 {
#   background-color: #ff1200;
#   color: #f1f1f1;
# }
# ...

# %%
cashDF = pd.read_csv('Cash-mortgage-sales-2025-04.csv',encoding='latin-1')
newCash = cashDF.head(500)
newCash.style.background_gradient(cmap='gist_rainbow')
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:3807: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:3808: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...
